# %% [markdown]
# Baixando data set
#
# Import do kaggle com conda prompt
#
# `conda install anaconda::kagglehub`

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("srgiomanhes/steam-games-dataset-2025")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 3.86M/3.86M [00:00<00:00, 4.90MB/s]
# Extracting model files...
# Path to dataset files: C:\Users\felfe\.cache\kagglehub\datasets\srgiomanhes\steam-games-dataset-2025\versions\3

# %%
import pandas as pd

# Substitua 'seu_arquivo.csv' pelo nome real do arquivo CSV do seu dataset.
# Com base na nossa pesquisa, pode ser algo como 'steam_games.csv'.
file_path = 'steam_games.csv'

# Carrega o dataset para um DataFrame
df = pd.read_csv(file_path)

# Visualiza as 100 primeiras linhas
display(df.head(100))
# Out:
#     steam_appid                                            name  \
# 0       2719580                                        勇者の伝説の勇者
# 1       2719590                                   Light No Fire
# 2       2719600                            Lorhaven: Cursed War
# 3       2719610                                    PUIQ: Demons
# 4       2719650                                  Project XSTING
# ..          ...                                             ...
# 95      2717330  Locked in a room while: Visiting an old Castle
# 96      2717390                                    Heading Home
# 97      2717400                                            霓虹人生
# 98      2717450          Museum Mystery: Deckbuilding Card Game
# 99      2717480                                        Envelope
#
#                                            developers  \
# 0                                            ['ぽけそう']
# 1                                     ['Hello Games']
# ...
